# %% [markdown]
# <a href="https://colab.research.google.com/github/Repollo1000/ADA-Informes/blob/main/Informe__InsertionSort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Problema de ordenamiento
#
# El problema de ordenamiento cosiste en una entrada de n numeros desordenados donde la salida de los numeros tiene que estar ordenado de menor a mayor o al revés.
#
# Ejemplo:
# ```
# Entrada:  [5, 2, 4, 6, 1, 3]
# Salida:  [1, 2, 3, 4, 5, 6]
# ```
# ![Sorting_insertion_sort_anim.gif](data:image/gif;base64,...)
#
#
#
# Este problema a sido analizado y resuelto por muchos investigadores, por lo que ha surguido una gran variedad de algoritmos que resuelven el mismo problema, han nacido una serie de conceptos como notación de O mayúscula, algoritmos divide y vencerás, estructuras de datos, análisis de los casos peor, mejor, y promedio, y límites inferiores, esto es bueno para saber cual es mejor algoritmo dependiendo de lo que se necesite.

# %% [markdown]
# ## 2.   Insertion sort
#
# El siguiente código muestra una implementación del algoritmo Insertion sort con complejidad temporal O(n^2)
#
# En el codigo se ingresa un arreglo de tamaño n y ordena el arreglo de menor a mayor con los mismos datos de entrada.

# %% [markdown]
# ### 2.1.Código

# %%
import random
from termcolor import colored
import copy

def insertionSort(arr,verbose=False):
  com = 0
  n = len(arr)
  if (verbose == True): print("Input array: ", arr)

  
  for i in range(1, len(arr) ):
      if verbose == True: print("\nPasada",i)
      already_sorted = True
      j = i           

      while arr[j - 1] > arr[j] and j > 0:
          arr[j - 1], arr[j] = arr[j], arr[j - 1]
          j -= 1
          com+= 1
          
          if verbose == True: 
            print("swap %d:" % com)
            print(str(arr[:j])[1:-1],",",colored(f"{str(arr[j:j+2])[1:-1]}","red"),",",str(arr[j+2:])[1:-1])


      if  verbose == True: 
           print("\nAl finalizar pasada:")
           #print("Pasada",i)
           print("[",colored(f"{str(arr[:i])[1:-1]}","blue") ,",", str(arr[i:])[1:-1],"]")
          
  return arr ,com

com = 0
print("Insertion sort")
arr = [5, 2, 4, 6, 1, 3]

print("Entrada: ",arr,"\n")

(arr , com) = insertionSort(arr)

print("Salida: ",arr)

#print("swap: ",com)
# Out:
# Insertion sort
# Entrada:  [5, 2, 4, 6, 1, 3]
#
# Salida:  [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ## **2.2.Descripción del algoritmo**
#
# El algoritmo recibe una lista(o arreglo) con cierta cantidad de elementos que queremos ordenar. Los numeros se ordenan en la misma lista(o arreglo)
#
# En palabras simple en cada iteracion se verifica que el numero analizado no tenga un numero mayor a su izquierda.
#
#
#
# 1.   En cada iterción el algoritmo verifica que ```arr[j]``` sea mayor a ```0``` también compara ``` arr[j-1] > arr[j]```.
# 2.   Si el algoritmo se encuentra ordenado no realiza cambios por que no se cumple la condicion necesaria.
# 3.   El algoritmo no requiere de una variable auxiliar aun que existen variantes que si la usan.
#
# ![Insertionsort-before.png](data:image/png;base64,...)
#
#
# ## **2.3.Ejemplo**
#
# Ejemplo de como se hacen las comparaciones.
#
# arr = [5, 2, 4, 6, 1, 3]
#
# En la primera parte
#
# No se realizan cambios porque el 5 no tiene un numero menor a el a su izquierda.
#
# arr = [5, 2, 4, 6, 1, 3]
#
# posteriormente el 5 se marca como sorted(ordenado) y el 2 se compara con el 5 y se hace el cambio por que el 2 < 5.
#
# arr = [2, 5, 4, 6, 1, 3]
#
# luego el 4 se cambia con el 5
#
# arr = [2, 4, 5, 6, 1, 3]
#
# No se generan cambios porque el 6 no tiene un numero mayor a la izquierda.
#
# arr = [2, 4, 5, 6, 1, 3]
#
# Después el uno se compara susecivamente con el de la izquierda hasta no tener un numero mayor a su lado
#
# arr = [1, 2, 4, 5, 6, 3]
#
# Pro ultimo el 3 se compara susecivamente con el de la izquierda hasta no tener un numero mayor a su lado
#
# arr = [1, 2, 3, 4, 5, 6]
#
# ## 2.4.Ejecución del algoritmo paso a paso

# %%
arr = [5, 2, 4, 6, 1, 3]
(arr) = insertionSort(arr,verbose = True)
print("swap toltales: ",com)
# Out:
# Input array:  [5, 2, 4, 6, 1, 3]
#
# Pasada 1
# swap 1:
#  , 2, 5 , 4, 6, 1, 3
#
# Al finalizar pasada:
# [ 2 , 5, 4, 6, 1, 3 ]
#
# Pasada 2
# swap 2:
# 2 , 4, 5 , 6, 1, 3
#
# Al finalizar pasada:
# [ 2, 4 , 5, 6, 1, 3 ]
#
# Pasada 3
#
# Al finalizar pasada:
# [ 2, 4, 5 , 6, 1, 3 ]
#
# Pasada 4
# swap 3:
# 2, 4, 5 , 1, 6 , 3
# swap 4:
# 2, 4 , 1, 5 , 6, 3
# swap 5:
# 2 , 1, 4 , 5, 6, 3
# swap 6:
#  , 1, 2 , 4, 5, 6, 3
#
# Al finalizar pasada:
# [ 1, 2, 4, 5 , 6, 3 ]
#
# Pasada 5
# swap 7:
# 1, 2, 4, 5 , 3, 6 ,
# swap 8:
# 1, 2, 4 , 3, 5 , 6
# swap 9:
# 1, 2 , 3, 4 , 5, 6
#
# Al finalizar pasada:
# [ 1, 2, 3, 4, 5 , 6 ]
# swap toltales:  9

# %% [markdown]
# ## **3. Tiempo de ejecucion**
#
# ### **Teorema(Tiempo de ejecución)**
#
# *   El peor caso: (n^2)Θ.
# *   El mejor caso: (n)Θ.
# *   El caso promedio para un arreglo aleatorio: (n^2)Θ.
#
# En el mejor caso, ocurre cuando el algoritmo esta completamente ordenado por que no realiza cambios, el tiempo seria lineal(O(1)).
#
# El pero caso seria cuando esta ordenado de mayor a menor por que tendria que realizar una gran cantidad de comparaciones, el tiempo de ejecución seria (O(n^2)) .
#
# Prueba del teorema en el pero caso.

# %%
arrPeorCaso = [6, 5, 4, 3, 2 , 1]
(arrPeorCaso) = insertionSort(arrPeorCaso,verbose = True)
#print("Comparaciones toltales: ",com)
# Out:
# Input array:  [6, 5, 4, 3, 2, 1]
#
# Pasada 1
# swap 1:
#  , 5, 6 , 4, 3, 2, 1
#
# Al finalizar pasada:
# [ 5 , 6, 4, 3, 2, 1 ]
#
# Pasada 2
# swap 2:
# 5 , 4, 6 , 3, 2, 1
# swap 3:
#  , 4, 5 , 6, 3, 2, 1
#
# Al finalizar pasada:
# [ 4, 5 , 6, 3, 2, 1 ]
#
# Pasada 3
# swap 4:
# 4, 5 , 3, 6 , 2, 1
# swap 5:
# 4 , 3, 5 , 6, 2, 1
# swap 6:
#  , 3, 4 , 5, 6, 2, 1
#
# Al finalizar pasada:
# [ 3, 4, 5 , 6, 2, 1 ]
#
# Pasada 4
# swap 7:
# 3, 4, 5 , 2, 6 , 1
# swap 8:
# 3, 4 , 2, 5 , 6, 1
# swap 9:
# 3 , 2, 4 , 5, 6, 1
# swap 10:
#  , 2, 3 , 4, 5, 6, 1
#
# Al finalizar pasada:
# [ 2, 3, 4, 5 , 6, 1 ]
#
# Pasada 5
# swap 11:
# 2, 3, 4, 5 , 1, 6 ,
# swap 12:
# 2, 3, 4 , 1, 5 , 6
# swap 13:
# 2, 3 , 1, 4 , 5, 6
# swap 14:
# 2 , 1, 3 , 4, 5, 6
# swap 15:
#  , 1, 2 , 3, 4, 5, 6
#
# Al finalizar pasada:
# [ 1, 2, 3, 4, 5 , 6 ]

# %% [markdown]
# ```
# [6, 5, 4, 3, 2 , 1]
# Salida ordenada: [1, 2, 3, 4, 5 , 6]
# Total de comparaciones realizadas: 15
# ```
# En este caso

# %% [markdown]
# ## **4. Correctitud**
# ### **Teorema (Correctitud).**
#
# Este algoritmo siempre
#
# **Prueba del teorema**
#
# En cada pasada podemos obtener a un sub arreglo ordenado desde i-1 hasta i=0, con los mismos elementos del arreglo original que se ingresaron.
#
# Desmostración de de la propiedad invariante de bucle insertion Sort.
#
# **Al comienzo de la i-ésima iteración**
#
#
# > Se asume que el sub arreglo esta ordenado por que i estara en la posicion i = 0 (i[6]).
#
#
#
# **Durante la i-ésima iteración**
#
# > Simepre se va cumplir la misma propiedad de (i - 1) hasta (i = 0), de que el sub arreglo siempre va estar ordenado, por ejemplo el gift donde el sorted representa al sub arreglo.
#
# ![insertion sort.gif](data:image/gif;base64,...)

# %% [markdown]
# ## **5. Experimentos**
#
# ### **5.1. Número de comparaciones**

# %%
import matplotlib.pyplot as plt

x=[n for n in range(5,20)] 
y1=[n*(n-1)/2 for n in range(5,20)] # worst case
y2=[n-1 for n in range(5,20)] # best case
y=[]; 

for n in range(5,20):
  a = random.sample(range(1, 100), n)
  a,counter = insertionSort(a)
  y.append(counter)

plt.plot(x,y)
plt.plot(x,y1)
plt.plot(x,y2)
plt.legend(["insertion Sort", "theoretical worst case", "theoretical best case"])

plt.xlabel('n')
plt.ylabel('number of operations')
plt.show()

# %% [markdown]
# El mejor caso, tiene una una menor cantidad de operación que el peor caso, en los casos aleatorios se puede apreciar que esta entre el mejor caso y el peor caso y no tiene un número de operaciones constante.

# %% [markdown]
# ### **5.2. Tiempo de ejecución (experimental)**

# %%
import matplotlib.pyplot as plt
import datetime
from timeit import repeat

x=[]; y=[]

for n in range(5,500):

  a = random.sample(range(1, 1000), n)

  #la función repeat está ejecutando 20 veces insertionSort con el arreglo a y retorna el mejor tiepo obtenido.
  t = repeat(setup="from __main__ import insertionSort", stmt=f"insertionSort({a})", repeat=1, number=10)

  x.append(n)
  y.append(t)


plt.plot(x,y)
plt.legend(["insertionSort"])

plt.xlabel('n')
plt.ylabel('time in ms')
plt.show()

# %% [markdown]
# En función del nivel del problema, es como se comporta a menor nivel del problema menos se demora y a mayor nivel, de problema más se demora. Analizando el tipo de gráfico se comporta parecido a una funcion cuadratica.
